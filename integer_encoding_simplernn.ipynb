# %% [markdown]
# <a href="https://colab.research.google.com/github/AdeelAsghar11/deep-learning-playground/blob/main/integer_encoding_simplernn.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np

docs = ['neural networks are cool',
        'deep learning deep learning',
        'train the model',
        'data data data',
        'gpu go brrr',
        'overfit overfit fix it',
        'transformers changed everything',
        'attention is all you need',
        'pytorch or tensorflow',
        'backprop backprop backprop',
        'more data more data',
        'gradient descent works',
        'loss is going down',
        'deploy the model',
        'llm llm llm',
        'ai is the future',
        'fine tune fine tune']

# %%
from tensorflow.keras.preprocessing.text import Tokenizer
tokenizer = Tokenizer(oov_token='<nothing>')

# %%
tokenizer.fit_on_texts(docs)

# %%
tokenizer.word_index
# Out:
# {'<nothing>': 1,
#  'data': 2,
#  'the': 3,
#  'is': 4,
#  'backprop': 5,
#  'llm': 6,
#  'deep': 7,
#  'learning': 8,
#  'model': 9,
#  'overfit': 10,
#  'more': 11,
#  'fine': 12,
#  'tune': 13,
#  'neural': 14,
#  'networks': 15,
#  'are': 16,
#  'cool': 17,
#  'train': 18,
#  'gpu': 19,
#  'go': 20,
#  'brrr': 21,
#  'fix': 22,
#  'it': 23,
#  'transformers': 24,
#  'changed': 25,
#  'everything': 26,
#  'attention': 27,
#  'all': 28,
#  'you': 29,
#  'need': 30,
#  'pytorch': 31,
#  'or': 32,
#  'tensorflow': 33,
#  'gradient': 34,
#  'descent': 35,
#  'works': 36,
#  'loss': 37,
#  'going': 38,
#  'down': 39,
#  'deploy': 40,
#  'ai': 41,
#  'future': 42}

# %%
tokenizer.word_counts
# Out:
# OrderedDict([('neural', 1),
#              ('networks', 1),
#              ('are', 1),
#              ('cool', 1),
#              ('deep', 2),
#              ('learning', 2),
#              ('train', 1),
#              ('the', 3),
#              ('model', 2),
#              ('data', 5),
#              ('gpu', 1),
#              ('go', 1),
#              ('brrr', 1),
#              ('overfit', 2),
#              ('fix', 1),
#              ('it', 1),
#              ('transformers', 1),
#              ('changed', 1),
#              ('everything', 1),
#              ('attention', 1),
#              ('is', 3),
#              ('all', 1),
#              ('you', 1),
#              ('need', 1),
#              ('pytorch', 1),
#              ('or', 1),
#              ('tensorflow', 1),
#              ('backprop', 3),
#              ('more', 2),
#              ('gradient', 1),
#              ('descent', 1),
#              ('works', 1),
#              ('loss', 1),
#              ('going', 1),
# ...

# %%
tokenizer.document_count
# Out:
# 17

# %%
sequences = tokenizer.texts_to_sequences(docs)
sequences
# Out:
# [[14, 15, 16, 17],
#  [7, 8, 7, 8],
#  [18, 3, 9],
#  [2, 2, 2],
#  [19, 20, 21],
#  [10, 10, 22, 23],
#  [24, 25, 26],
#  [27, 4, 28, 29, 30],
#  [31, 32, 33],
#  [5, 5, 5],
#  [11, 2, 11, 2],
#  [34, 35, 36],
#  [37, 4, 38, 39],
#  [40, 3, 9],
#  [6, 6, 6],
#  [41, 4, 3, 42],
#  [12, 13, 12, 13]]

# %%
from keras.utils import pad_sequences

# %%
sequences = pad_sequences(sequences,padding='post')

# %%
sequences
# Out:
# array([[14, 15, 16, 17,  0],
#        [ 7,  8,  7,  8,  0],
#        [18,  3,  9,  0,  0],
#        [ 2,  2,  2,  0,  0],
#        [19, 20, 21,  0,  0],
#        [10, 10, 22, 23,  0],
#        [24, 25, 26,  0,  0],
#        [27,  4, 28, 29, 30],
#        [31, 32, 33,  0,  0],
#        [ 5,  5,  5,  0,  0],
#        [11,  2, 11,  2,  0],
#        [34, 35, 36,  0,  0],
#        [37,  4, 38, 39,  0],
#        [40,  3,  9,  0,  0],
#        [ 6,  6,  6,  0,  0],
#        [41,  4,  3, 42,  0],
#        [12, 13, 12, 13,  0]], dtype=int32)

# %%
from keras.datasets import imdb
from keras import Sequential
from keras.layers import Dense,SimpleRNN,Embedding,Flatten

# %%
(X_train,y_train),(X_test,y_test) = imdb.load_data()
# Out:
# ...
# 17464789/17464789 ━━━━━━━━━━━━━━━━━━━━ 0s 0us/step

# %%
X_train[0]
# Out:
# [1,
#  14,
#  22,
#  16,
#  43,
#  530,
#  973,
#  1622,
#  1385,
#  65,
#  458,
#  4468,
#  66,
#  3941,
#  4,
#  173,
#  36,
#  256,
#  5,
#  25,
#  100,
#  43,
#  838,
#  112,
#  50,
#  670,
#  22665,
#  9,
#  35,
#  480,
#  284,
#  5,
#  150,
#  4,
#  172,
#  112,
#  167,
#  21631,
#  336,
#  385,
#  39,
#  4,
#  172,
#  4536,
#  1111,
#  17,
#  546,
#  38,
#  13,
#  447,
#  4,
#  192,
#  50,
#  16,
#  6,
#  147,
#  2025,
#  19,
#  14,
#  22,
#  4,
#  1920,
#  4613,
#  469,
#  4,
#  22,
#  71,
#  87,
#  12,
#  16,
#  43,
#  530,
#  38,
#  76,
#  15,
#  13,
#  1247,
#  4,
#  22,
#  17,
#  515,
#  17,
#  12,
#  16,
#  626,
#  18,
#  19193,
#  5,
#  62,
#  386,
#  12,
#  8,
#  316,
#  8,
#  106,
#  5,
#  4,
#  2223,
#  5244,
#  16,
#  480,
#  66,
#  3785,
#  33,
#  4,
#  130,
#  12,
#  16,
#  38,
#  619,
#  5,
#  25,
#  124,
#  51,
#  36,
#  135,
#  48,
#  25,
#  1415,
#  33,
#  6,
#  22,
#  12,
#  215,
#  28,
#  77,
#  52,
#  5,
#  14,
#  407,
#  16,
#  82,
#  10311,
#  8,
#  4,
# ...

# %%
len(X_train[2])
# Out:
# 141

# %%
X_train = pad_sequences(X_train,padding='post',maxlen=50)
X_test = pad_sequences(X_test,padding='post',maxlen=50)

# %%
X_train[0]
# Out:
# array([2071,   56,   26,  141,    6,  194, 7486,   18,    4,  226,   22,
#          21,  134,  476,   26,  480,    5,  144,   30, 5535,   18,   51,
#          36,   28,  224,   92,   25,  104,    4,  226,   65,   16,   38,
#        1334,   88,   12,   16,  283,    5,   16, 4472,  113,  103,   32,
#          15,   16, 5345,   19,  178,   32], dtype=int32)

# %%
model = Sequential()

model.add(SimpleRNN(32,input_shape=(50,1),return_sequences=False))
model.add(Dense(1,activation='sigmoid'))

model.summary()
# Out:
# /usr/local/lib/python3.12/dist-packages/keras/src/layers/rnn/rnn.py:199: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(**kwargs)
# Model: "sequential"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ simple_rnn (SimpleRNN)          │ (None, 32)             │         1,088 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense (Dense)                   │ (None, 1)              │            33 │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 1,121 (4.38 KB)
#  Trainable params: 1,121 (4.38 KB)
#  Non-trainable params: 0 (0.00 B)

# %%
model.compile(loss='binary_crossentropy',optimizer='adam',metrics=['accuracy'])

model.fit(X_train,y_train,epochs=5,validation_data=(X_test,y_test))
# Out:
# Epoch 1/5
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 20s 23ms/step - accuracy: 0.5084 - loss: 0.6977 - val_accuracy: 0.5024 - val_loss: 0.6943
# Epoch 2/5
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 11s 14ms/step - accuracy: 0.5076 - loss: 0.6931 - val_accuracy: 0.5037 - val_loss: 0.6942
# Epoch 3/5
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 11s 14ms/step - accuracy: 0.5056 - loss: 0.6929 - val_accuracy: 0.5060 - val_loss: 0.6939
# Epoch 4/5
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 12s 16ms/step - accuracy: 0.5059 - loss: 0.6927 - val_accuracy: 0.4987 - val_loss: 0.6944
# Epoch 5/5
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 12s 15ms/step - accuracy: 0.5104 - loss: 0.6927 - val_accuracy: 0.5057 - val_loss: 0.6934
