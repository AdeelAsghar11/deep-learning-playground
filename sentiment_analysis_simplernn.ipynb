# %% [markdown]
# <a href="https://colab.research.google.com/github/AdeelAsghar11/deep-learning-playground/blob/main/sentiment_analysis_simplernn.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
docs = ['neural networks are cool',
        'deep learning deep learning',
        'train the model',
        'data data data',
        'gpu go brrr',
        'overfit overfit fix it',
        'transformers changed everything',
        'attention is all you need',
        'pytorch or tensorflow',
        'backprop backprop backprop',
        'more data more data',
        'gradient descent works',
        'loss is going down',
        'deploy the model',
        'llm llm llm',
        'ai is the future',
        'fine tune fine tune']

# %%
from tensorflow.keras.preprocessing.text import Tokenizer
tokenizer = Tokenizer()

# %%
tokenizer.fit_on_texts(docs)

# %%
len(tokenizer.word_index)
# Out:
# 41

# %%
sequences = tokenizer.texts_to_sequences(docs)
sequences
# Out:
# [[13, 14, 15, 16],
#  [6, 7, 6, 7],
#  [17, 2, 8],
#  [1, 1, 1],
#  [18, 19, 20],
#  [9, 9, 21, 22],
#  [23, 24, 25],
#  [26, 3, 27, 28, 29],
#  [30, 31, 32],
#  [4, 4, 4],
#  [10, 1, 10, 1],
#  [33, 34, 35],
#  [36, 3, 37, 38],
#  [39, 2, 8],
#  [5, 5, 5],
#  [40, 3, 2, 41],
#  [11, 12, 11, 12]]

# %%
from keras.utils import pad_sequences
sequences = pad_sequences(sequences,padding='post')
sequences
# Out:
# array([[13, 14, 15, 16,  0],
#        [ 6,  7,  6,  7,  0],
#        [17,  2,  8,  0,  0],
#        [ 1,  1,  1,  0,  0],
#        [18, 19, 20,  0,  0],
#        [ 9,  9, 21, 22,  0],
#        [23, 24, 25,  0,  0],
#        [26,  3, 27, 28, 29],
#        [30, 31, 32,  0,  0],
#        [ 4,  4,  4,  0,  0],
#        [10,  1, 10,  1,  0],
#        [33, 34, 35,  0,  0],
#        [36,  3, 37, 38,  0],
#        [39,  2,  8,  0,  0],
#        [ 5,  5,  5,  0,  0],
#        [40,  3,  2, 41,  0],
#        [11, 12, 11, 12,  0]], dtype=int32)

# %%
from tensorflow import keras
from keras.models import Sequential
from keras.layers import Dense,SimpleRNN,Embedding,Flatten

model = Sequential()
model.add(Embedding(17,output_dim=2,input_length=5))

model.summary()
# Out:
# /usr/local/lib/python3.12/dist-packages/keras/src/layers/core/embedding.py:100: UserWarning: Argument `input_length` is deprecated. Just remove it.
#   warnings.warn(
# Model: "sequential"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ embedding (Embedding)           │ ?                      │   0 (unbuilt) │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 0 (0.00 B)
#  Trainable params: 0 (0.00 B)
#  Non-trainable params: 0 (0.00 B)

# %%
model.compile('adam','accuracy')

# %%
pred = model.predict(sequences)
print(pred)
# Out:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 931ms/step
# [[[ 0.03667202 -0.03535108]
#   [ 0.00600068  0.01748675]
#   [ 0.01012025  0.01372745]
#   [ 0.03995879 -0.01152942]
#   [-0.02040473  0.0306661 ]]
#
#  [[-0.02831076  0.04270839]
#   [-0.01791725  0.02256143]
#   [-0.02831076  0.04270839]
#   [-0.01791725  0.02256143]
#   [-0.02040473  0.0306661 ]]
#
#  [[ 0.03995879 -0.01152942]
#   [ 0.04871118 -0.01598911]
#   [-0.03928018  0.00383844]
#   [-0.02040473  0.0306661 ]
#   [-0.02040473  0.0306661 ]]
#
#  [[ 0.0053046  -0.007909  ]
#   [ 0.0053046  -0.007909  ]
#   [ 0.0053046  -0.007909  ]
#   [-0.02040473  0.0306661 ]
#   [-0.02040473  0.0306661 ]]
#
#  [[ 0.03995879 -0.01152942]
#   [ 0.03995879 -0.01152942]
#   [ 0.03995879 -0.01152942]
#   [-0.02040473  0.0306661 ]
#   [-0.02040473  0.0306661 ]]
#
#  [[-0.02048185 -0.0233952 ]
#   [-0.02048185 -0.0233952 ]
#   [ 0.03995879 -0.01152942]
#   [ 0.03995879 -0.01152942]
#   [-0.02040473  0.0306661 ]]
#
#  [[ 0.03995879 -0.01152942]
# ...

# %%
from keras.datasets import imdb
from keras.utils import pad_sequences
from keras import Sequential
from keras.layers import Dense,SimpleRNN,Embedding,Flatten

# %%
(X_train,y_train),(X_test,y_test) = imdb.load_data()
# Out:
# ...
# 17464789/17464789 ━━━━━━━━━━━━━━━━━━━━ 1s 0us/step

# %%
X_train = pad_sequences(X_train,padding='post',maxlen=50)
X_test = pad_sequences(X_test,padding='post',maxlen=50)

# %%
X_train.shape
# Out:
# (25000, 50)

# %%
from tensorflow.keras.layers import Input

model = Sequential()
model.add(Input(shape=(50,)))          # 👈 explicit input layer
model.add(Embedding(10000, 2))
model.add(SimpleRNN(32, return_sequences=False))
model.add(Dense(1, activation='sigmoid'))

model.summary()
# Out:
# Model: "sequential_5"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ embedding_5 (Embedding)         │ (None, 50, 2)          │        20,000 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ simple_rnn_3 (SimpleRNN)        │ (None, 32)             │         1,120 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_3 (Dense)                 │ (None, 1)              │            33 │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 21,153 (82.63 KB)
#  Trainable params: 21,153 (82.63 KB)
#  Non-trainable params: 0 (0.00 B)

# %%
model.compile(optimizer='adam', loss='binary_crossentropy', metrics=['acc'])
history = model.fit(X_train, y_train,epochs=5,validation_data=(X_test,y_test))
# Out:
# Epoch 1/5
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 11s 11ms/step - acc: 0.5894 - loss: 0.6479 - val_acc: 0.7769 - val_loss: 0.4707
# Epoch 2/5
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 7s 9ms/step - acc: 0.8081 - loss: 0.4184 - val_acc: 0.8100 - val_loss: 0.4208
# Epoch 3/5
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 7s 9ms/step - acc: 0.8537 - loss: 0.3503 - val_acc: 0.8035 - val_loss: 0.4392
# Epoch 4/5
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 6s 8ms/step - acc: 0.8610 - loss: 0.3347 - val_acc: 0.7928 - val_loss: 0.4602
# Epoch 5/5
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 7s 9ms/step - acc: 0.8642 - loss: 0.3258 - val_acc: 0.7810 - val_loss: 0.5037
